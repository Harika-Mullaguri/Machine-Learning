# %% [markdown]
# <a href="https://colab.research.google.com/github/Harika-Mullaguri/Machine-Learning/blob/main/Market_basket_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! pip install mlxtend

# %%
groceries = pd.DataFrame([
    # --- Customer 1001 ---
    [1001, '2024-01-01', 'Milk'],
    [1001, '2024-01-01', 'Bread'],
    [1001, '2024-01-01', 'Eggs'],
    [1001, '2024-01-05', 'Butter'],
    [1001, '2024-01-05', 'Cheese'],

    # --- Customer 1002 ---
    [1002, '2024-01-02', 'Apples'],
    [1002, '2024-01-02', 'Bananas'],
    [1002, '2024-01-02', 'Orange Juice'],
    [1002, '2024-01-08', 'Cereal'],
    [1002, '2024-01-08', 'Milk'],

    # --- Customer 1003 ---
    [1003, '2024-01-02', 'Chicken'],
    [1003, '2024-01-02', 'Rice'],
    [1003, '2024-01-02', 'Seasoning'],
    [1003, '2024-01-10', 'Milk'],
    [1003, '2024-01-10', 'Bread'],

    # --- Customer 1004 ---
    [1004, '2024-01-03', 'Eggs'],
    [1004, '2024-01-03', 'Bacon'],
    [1004, '2024-01-03', 'Sausages'],
    [1004, '2024-01-07', 'Coffee'],
    [1004, '2024-01-07', 'Sugar'],

    # --- Customer 1005 ---
    [1005, '2024-01-04', 'Tomatoes'],
    [1005, '2024-01-04', 'Onions'],
    [1005, '2024-01-04', 'Cucumbers'],
    [1005, '2024-01-09', 'Pasta'],
    [1005, '2024-01-09', 'Tomato Sauce'],

    # --- Customer 1006 ---
    [1006, '2024-01-06', 'Milk'],
    [1006, '2024-01-06', 'Cornflakes'],
    [1006, '2024-01-06', 'Bananas'],
    [1006, '2024-01-11', 'Bread'],
    [1006, '2024-01-11', 'Eggs'],

    # --- Customer 1007 ---
    [1007, '2024-01-06', 'Chips'],
    [1007, '2024-01-06', 'Soda'],
    [1007, '2024-01-06', 'Chocolate'],
    [1007, '2024-01-12', 'Milk'],
    [1007, '2024-01-12', 'Cookies'],
], columns=['Member_number', 'Date', 'itemDescription'])

# %%
print(groceries)
# Out:
#     Member_number        Date itemDescription
# 0            1001  2024-01-01            Milk
# 1            1001  2024-01-01           Bread
# 2            1001  2024-01-01            Eggs
# 3            1001  2024-01-05          Butter
# 4            1001  2024-01-05          Cheese
# 5            1002  2024-01-02          Apples
# 6            1002  2024-01-02         Bananas
# 7            1002  2024-01-02    Orange Juice
# 8            1002  2024-01-08          Cereal
# 9            1002  2024-01-08            Milk
# 10           1003  2024-01-02         Chicken
# 11           1003  2024-01-02            Rice
# 12           1003  2024-01-02       Seasoning
# 13           1003  2024-01-10            Milk
# 14           1003  2024-01-10           Bread
# 15           1004  2024-01-03            Eggs
# 16           1004  2024-01-03           Bacon
# 17           1004  2024-01-03        Sausages
# 18           1004  2024-01-07          Coffee
# ...

# %%
groceries.describe()
# Out:
#        Member_number
# count      35.000000
# mean     1004.000000
# std         2.029199
# min      1001.000000
# 25%      1002.000000
# 50%      1004.000000
# 75%      1006.000000
# max      1007.000000

# %%
if not groceries.empty:
    groceries=groceries.groupby(['Member_number', 'Date'])['itemDescription'].apply(lambda x: ','.join(x)).reset_index()
    groceries.head()
else:
  print("no data")

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
te = TransactionEncoder()
te_ary = te.fit(groceries).transform(groceries)
print(te_ary)
# Out:
# [[False  True  True False  True False  True False  True  True False False
#    True False False  True]
#  [ True False False  True False False  True False False False False False
#   False False  True False]
#  [ True False False False False  True  True  True  True  True  True  True
#    True  True  True False]
#  [False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False]
# ...
